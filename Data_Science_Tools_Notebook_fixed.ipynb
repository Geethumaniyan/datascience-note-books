# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## Introduction
# This notebook showcases various data science languages, libraries, and tools.

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas
# 2. NumPy
# 3. Matplotlib

# %% [markdown]
# | Tool | Description |
# |------|-------------|
# | Jupyter Notebook | Interactive computing tool |
# | RStudio | IDE for R programming |
# | Apache Spark | Big data processing tool |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions:

# %%
# Adding two numbers
12 + 5
# Out:
# 17

# %%
# Dividing two numbers
10/3
# Out:
# 3.3333333333333335

# %% [markdown]
# **Objectives**
# - Learn data science languages
# - Explore libraries
# - Understand tools

# %% [markdown]
# ## Author
# geethu
